# %% [markdown]
# # Lab 1 - My solutions
# **Basics of numpy and matplotlib**<br>
# Software 1 - Mathematics<br>
# Information and Communication Technology<br>
# Metropolia University of Applied Sciences

# %% [markdown]
# ## Setup

# %%
name = "Matin Shahabi" # Write your name between the parenthesis
student_id = 2601221 # Change your student ID here
date_returned = "" # Write the date returned between the parenthesis

# %%
from IPython.display import Markdown, display
import numpy as np
import matplotlib.pyplot as plt
import labx as mx

# %%
from IPython.display import Markdown, display # IPython.display is used to display Markdown text in Jupyter notebooks
import numpy as np # numpy is used for numerical calculations
import matplotlib.pyplot as plt # matplotlib is used for plotting graphics
import labx as mx # Remember to download labx module from OMA assignment !!!

# %% [markdown]
# ---
# ## My solution for problem 1

# %%
x = np.arange(-10,10,0.001)
y = mx.lab_1_problem_1(x, 2602078)
plt.title("function f(x) for student 2601221")

plt.plot(x, y)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.show()

# %% [markdown]
# ---
# ## My solution for problem 2

# %%
plt.figure(figsize=(8,6))
plt.plot(x, y)
plt.xlim(-4,-3)
plt.ylim(0,2)
plt.axhline(y=1,color='r',linestyle='--')
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.title('point 1 - zoomed view')
plt.show()


## My solution for problem 2
plt.figure(figsize=(8, 6))
plt.plot(x, y)
plt.xlim(4, 5)
plt.ylim(0, 2)
plt.axhline(y=1, color='r', linestyle='--')
plt.xlabel("x")
plt.ylabel("f(x)")
plt.grid(True)
plt.title('point 1 - zoomed view')
plt.show()
